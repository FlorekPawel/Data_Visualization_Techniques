# %% [markdown]
# # matplotlib

# %% [markdown]
# Wizualizacje w matplotlib (książka) https://hal.inria.fr/hal-03427242/document

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2 * np.pi, 10)

# %%
y = np.sin(x)

# %%
print(x)
# Out:
# [0.         0.6981317  1.3962634  2.0943951  2.7925268  3.4906585
#  4.1887902  4.88692191 5.58505361 6.28318531]

# %% [markdown]
# ## Wykres liniowy

# %%
plt.plot(x)
plt.show() #potrzebne w niektórych IDE

# %% [markdown]
# #### modyfikacje

# %%
plt.plot(x, y)
plt.ylabel('sinus')
# Out:
# Text(0, 0.5, 'sinus')

# %%
plt.plot(x, y)
plt.ylabel('sinus')
plt.title("SINUS", loc = "left")
plt.show()

# %%
plt.plot(x, y, linestyle = "--")
plt.show()

# %%
plt.plot(x, y, color = "#371ea3")

# %% [markdown]
# Więcej: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
plt.plot(x, y, label = "sin")
plt.plot(x, -y, label = "-sin")
plt.legend()
plt.show()

# %% [markdown]
# ## Wykres słupkowy

# %%
names  = ['A', 'B', 'C']

# %%
values = [2, 8, 15]

# %%
plt.bar(names, values)
plt.show()

# %%
plt.barh(names, values)
plt.show()

# %%
plt.barh(names, values)
plt.plot(values, names, color = "green", marker = ".", markersize = 22)
plt.show()

# %% [markdown]
# Więcej: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.bar.html#matplotlib.pyplot.bar

# %% [markdown]
# ## Wykres punktowy

# %%
plt.scatter(names, values)
plt.show()

# %%
size = [10, 30, 90]
plt.scatter(names, values, s = size)
plt.show()

# %% [markdown]
# Więcej: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter

# %% [markdown]
# ## Histogram

# %%
x = np.random.randn(1000)

num_bins = 50

# %%
plt.hist(x, num_bins)
plt.show()

# %% [markdown]
# ## Figury

# %% [markdown]
# `plt.plot()` pozwala na narysowanie tylko jednej figury o współrzędnych (x,y)

# %%
names = ['X', 'Y', 'Z']
values = [3, 9, 27]

# %%
plt.bar(names, values)
plt.show()

# %% [markdown]
# `plt.figure()` definiuje figurę, możemy na niej umieszczać inne elementy

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1) #nrow, ncol, index
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1) #nrow, ncol, index
ax.bar(names, values)
plt.show()

# %% [markdown]
# `plt.subplot()` - pozwala na rysowanie jednej lub kilku figur w tym samym oknie

# %%
fig, (ax1, ax2) = plt.subplots(2, 1) #2 wiersze, 1 kolumna

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('Tytuł')

ax1.bar(names, values)
ax2.bar(names, [2,2,5])

plt.show()

# %% [markdown]
# # seaborn

# %%
import seaborn as sns
import pandas as pd

# %%
# opcje wyświetlania

# %%
sns.set(rc = {'figure.figsize': (12,7)})
sns.set_style("darkgrid")
pd.options.display.max_rows = 10
pd.set_option('display.width', 5000)
pd.set_option('display.max_columns', 60)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mini-pw/2021Z-DataVisualizationTechniques/master/labs/data/Pokemon.csv", index_col=0, sep=",")

# %%
df.head()

# %% [markdown]
# ## Wykres punktowy

# %%
sns.scatterplot(data=df, x='Attack', y='Defense')
plt.show()

# %%
sns.scatterplot(data=df, x='Attack', y='Defense', hue='Stage')
plt.show()

# %%
sns.scatterplot(data=df, x='Attack', y='Defense', size='Stage')
plt.show()

# %%
sns.scatterplot(data=df, x='Attack', y='Defense', hue='Stage')

plt.ylim(None, 150)
plt.xlim(-100, None)
plt.show()

# %% [markdown]
# ## boxplot

# %%
sns.boxplot(data=df)
plt.show()

# %%
sns.boxplot(data=df, color='w')
plt.show()

# %%
stats_df = df.drop(['Total', 'Stage', 'Legendary'], axis=1)

# %%
sns.boxplot(data=stats_df)
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(data=stats_df, x = 'Type 1', y = 'Attack')
plt.show()

# %% [markdown]
# ## violin plot

# %%
sns.violinplot(x = 'Type 1', y = 'Attack', data=df)
# Out:
# <AxesSubplot: xlabel='Type 1', ylabel='Attack'>

# %%
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

sns.violinplot(x='Type 1', y='Attack', data=df, 
               palette=pkmn_type_colors)
plt.show()

# %% [markdown]
# ## swarm plot

# %%
sns.swarmplot(x='Type 1', y='Attack', data=df, 
              palette=pkmn_type_colors)
plt.show()
# Out:
# C:\Users\pawfl\AppData\Local\Temp\ipykernel_764\3124415183.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='Type 1', y='Attack', data=df,

# %% [markdown]
# ## nakładanie wykresów

# %%
sns.violinplot(x='Type 1',
               y='Attack', 
               data=df, 
               inner=None, # usunięcie boxplotów ze środka
               palette=pkmn_type_colors)
 
sns.swarmplot(x='Type 1', 
              y='Attack', 
              data=df, 
              color='black')# czarne punkty
 
# Tytuł z matplotlib
plt.title('Attack by Type')
plt.show()

# %%
melted_df = pd.melt(stats_df, 
                    id_vars=["Name", "Type 1", "Type 2"], # Zmienne do zatrzymania
                    var_name="Stat") # Nazwa nowej zmiennej
melted_df
# Out:
#            Name   Type 1  Type 2   Stat  value
# 0     Bulbasaur    Grass  Poison     HP     45
# 1       Ivysaur    Grass  Poison     HP     60
# 2      Venusaur    Grass  Poison     HP     80
# 3    Charmander     Fire     NaN     HP     39
# 4    Charmeleon     Fire     NaN     HP     58
# ..          ...      ...     ...    ...    ...
# 901     Dratini   Dragon     NaN  Speed     50
# 902   Dragonair   Dragon     NaN  Speed     70
# 903   Dragonite   Dragon  Flying  Speed     80
# 904      Mewtwo  Psychic     NaN  Speed    130
# 905         Mew  Psychic     NaN  Speed    100
#
# [906 rows x 5 columns]

# %%
sns.boxplot(x='Stat', y='value', data=melted_df, 
              hue='Type 1')
plt.show()

# %%
# powiększamy wykres
plt.figure(figsize=(16,7))
 
sns.boxplot(x='Stat', 
              y='value', 
              data=melted_df, 
              hue='Type 1', 
              palette=pkmn_type_colors) # dodajemy paletę

# przenosimy legendę
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ## panele

# %%
g = sns.catplot(x='Type 1', 
                   y='Attack', 
                   data=df, 
                   hue='Stage',  # kolor
                   col='Stage',  # podział po Stage
                   kind='box') # typ
 
g.set_xticklabels(rotation=-45)
 
plt.show()

# %% [markdown]
# ## Zadanie

# %% [markdown]
# Narysować wykresy dla zbioru danych Titanic:
#
# a) histogram zmiennej fare
#
# b) boxplot wieku w podziale na płeć
#
# c) wykres słupkowy pokazujący liczbę pasażerów w każdej z trzech klas
#
# d) procent osób, które przeżyły (survived) w każdej z klas

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0         0       3    male  22.0      1      0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1         1       1  female  38.0      1      0  71.2833        C  First  woman       False    C    Cherbourg   yes  False
# 2         1       3  female  26.0      0      0   7.9250        S  Third  woman       False  NaN  Southampton   yes   True
# 3         1       1  female  35.0      1      0  53.1000        S  First  woman       False    C  Southampton   yes  False
# 4         0       3    male  35.0      0      0   8.0500        S  Third    man        True  NaN  Southampton    no   True

# %%
#a
sns.histplot(data= titanic, x= 'fare', bins= 20)
# Out:
# <AxesSubplot: xlabel='fare', ylabel='Count'>

# %%
sns.scatterplot(data= titanic, x= 'age', y= 'fare', hue= 'survived')
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(data= titanic, x= 'age', y= 'fare', hue= 'sex')
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
#b
sns.boxplot(data= titanic, x= "sex", y= "age")
# Out:
# <AxesSubplot: xlabel='sex', ylabel='age'>

# %%
#c
tmp = titanic.groupby('class').survived.count().reset_index(name = 'count')
sns.barplot(data= tmp, x= 'class', y= 'count', color='blue')
# Out:
# <AxesSubplot: xlabel='class', ylabel='count'>

# %%
tmp = titanic["class"].value_counts().reset_index(name = 'count')
sns.barplot(data= tmp, x = 'index', y= 'count', color='blue')
# Out:
# <AxesSubplot: xlabel='index', ylabel='count'>

# %%
#d
tmp = titanic.loc[titanic['survived']==1].groupby(['class']).age.count().reset_index(name = 'count')
tmp1 = titanic.groupby(['class']).survived.count().reset_index(name = 'total')
df = pd.merge(tmp, tmp1)
df['percentage'] = df['count']/df['total'] *100
df = df.drop(['count', 'total'], axis = 1)

sns.barplot(data= df, x = 'class', y= 'percentage', color='grey')
# Out:
# <AxesSubplot: xlabel='class', ylabel='percentage'>
